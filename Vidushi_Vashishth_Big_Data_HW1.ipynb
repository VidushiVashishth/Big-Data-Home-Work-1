# %%
import tensorflow as tf
import time

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first 25 images from the training set and display the class name below each image:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# # Big Data HW1 : Step (1) Creating Dataset Variations

# %% [markdown]
# Downscaling Images from 32*32 to 16*16 pixels

# %%
from PIL import Image
import numpy as np

train_images_16_16 = np.empty([int(train_images.shape[0]), int(train_images.shape[1]/2), int(train_images.shape[2]/2), int(train_images.shape[3])])
for idx,train_image in enumerate(train_images):
    im = Image.fromarray((train_image*255).astype(np.uint8))
    im_resize = im.resize((im.width//2, im.height//2))
    im_downscale = np.array(im_resize.getdata()).reshape((im_resize.size[0],im_resize.size[1],3))
    train_images_16_16[idx] = im_downscale

# %%
test_images_16_16 = np.empty([int(test_images.shape[0]), int(test_images.shape[1]/2), int(test_images.shape[2]/2), int(test_images.shape[3])])
for idx,test_image in enumerate(test_images):
    im = Image.fromarray((test_image*255).astype(np.uint8))
    im_resize = im.resize((im.width//2, im.height//2))
    im_downscale = np.array(im_resize.getdata()).reshape((im_resize.size[0],im_resize.size[1],3))
    test_images_16_16[idx] = im_downscale

# %%
#ORIGINAL IMAGE
plt.figure()
plt.imshow(Image.fromarray((train_images[60]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#REDUCED RESOLUTION IMAGE
plt.figure()
plt.imshow(Image.fromarray((train_images_16_16[60]).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images_16_16 = train_images_16_16/255
test_images_16_16 = test_images_16_16/255

# %% [markdown]
# ### Verify lower resolution dataset

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images_16_16[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ### Utility functions for modular coding

# %%
def create_model(pixel, max_pool_parameter):
    model = models.Sequential()
    model.add(layers.Conv2D(pixel, (3, 3), activation='relu', input_shape=(pixel, pixel, 3)))
    model.add(layers.MaxPooling2D((max_pool_parameter, max_pool_parameter)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((max_pool_parameter, max_pool_parameter)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10))
    return model

# %%
def train_model(model, model_name, train_data, train_label, test_data, test_label):
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

    t0 = time.time()
    history = model.fit(train_data, train_label, epochs=10, validation_data=(test_data, test_label))
    t1 = time.time()
    print("Total training time to train ", model_name, t1-t0)
    model.save(model_name+'.h5')
    return history, model

# %%
def train_model_only_CPU(model, model_name, train_data, train_label, test_data, test_label):
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

    t0 = time.time()
    with tf.device('/CPU:0'):
        history = model.fit(train_data, train_label, epochs=10, validation_data=(test_data, test_label))
    t1 = time.time()
    print("Total training time to train ", model_name, t1-t0)
    model.save(model_name+'.h5')
    return history, model

# %%
def evaluate_model(fig_name, model, history, test_data, test_model):
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0.5, 1])
    plt.legend(loc='lower right')
    plt.savefig(fig_name+'.png')

    test_loss, test_acc = model.evaluate(test_data, test_model, verbose=2)
    print('Validation accuracy ', test_acc)

# %% [markdown]
# # Training with CPU + GPU

# %% [markdown]
# ### Compile, train and calculate accuracy of model for 32*32 full size dataset

# %%
model1 = create_model(32, 2)
history1, model1 = train_model(model1, '32_32_complete', train_images, train_labels, test_images, test_labels)
evaluate_model('32_32_complete', model1, history1, test_images, test_labels)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x163a4e160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x163a4e160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2021-09-11 00:08:27.811260: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-11 00:08:27.811443: W tensorflow/core/platform/profile_utils/cpu_utils.cc:126] Failed to get CPU frequency: 0 Hz
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.7388 - accuracy: 0.3544WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x177fb2af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x177fb2af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.7384 - accuracy: 0.3546 - val_loss: 1.3094 - val_accuracy: 0.5254
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1923 - accuracy: 0.5757 - val_loss: 1.1096 - val_accuracy: 0.6104
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0004 - accuracy: 0.6511 - val_loss: 0.9730 - val_accuracy: 0.6590
# Epoch 4/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8826 - accuracy: 0.6925 - val_loss: 0.9228 - val_accuracy: 0.6813
# Epoch 5/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8114 - accuracy: 0.7137 - val_loss: 0.9088 - val_accuracy: 0.6849
# Epoch 6/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7448 - accuracy: 0.7386 - val_loss: 0.8856 - val_accuracy: 0.6964
# Epoch 7/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6856 - accuracy: 0.7611 - val_loss: 1.0232 - val_accuracy: 0.6623
# Epoch 8/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6432 - accuracy: 0.7750 - val_loss: 0.8569 - val_accuracy: 0.7121
# Epoch 9/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6045 - accuracy: 0.7875 - val_loss: 0.8518 - val_accuracy: 0.7081
# Epoch 10/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5657 - accuracy: 0.8021 - val_loss: 0.8621 - val_accuracy: 0.7140
# Total training time to train  32_32_complete 112.81267404556274
# 313/313 - 1s - loss: 0.8621 - accuracy: 0.7140
# Validation accuracy  0.7139999866485596

# %% [markdown]
# ### Compile, train and calculate accuracy of model for 32*32 reduced size dataset

# %%
#Sampling images from train dataset for reduced dataset model evaluation
validation_images = train_images[49000:]
validation_labels = train_labels[49000:]

# %%
#Training on test dataset as it is smaller in size. Have sliced 1000 rows from the training dataset for validation here. 
model2 = create_model(32, 2)
history2, model2 = train_model(model2, '32_32_smaller_dataset', test_images, test_labels, validation_images, validation_labels)
evaluate_model('32_32_smaller_dataset', model2, history2, validation_images, validation_labels)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29db4a310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29db4a310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 306/313 [============================>.] - ETA: 0s - loss: 2.1455 - accuracy: 0.1917WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x29c84da60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x29c84da60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 313/313 [==============================] - 3s 8ms/step - loss: 2.1415 - accuracy: 0.1935 - val_loss: 1.6817 - val_accuracy: 0.3830
# Epoch 2/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.6607 - accuracy: 0.3896 - val_loss: 1.5367 - val_accuracy: 0.4620
# Epoch 3/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4835 - accuracy: 0.4609 - val_loss: 1.4144 - val_accuracy: 0.4930
# Epoch 4/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.3796 - accuracy: 0.4978 - val_loss: 1.3154 - val_accuracy: 0.5340
# Epoch 5/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.2785 - accuracy: 0.5394 - val_loss: 1.3108 - val_accuracy: 0.5270
# Epoch 6/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1989 - accuracy: 0.5824 - val_loss: 1.2652 - val_accuracy: 0.5540
# Epoch 7/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1498 - accuracy: 0.5983 - val_loss: 1.2409 - val_accuracy: 0.5400
# Epoch 8/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0519 - accuracy: 0.6304 - val_loss: 1.2774 - val_accuracy: 0.5460
# Epoch 9/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0020 - accuracy: 0.6466 - val_loss: 1.1877 - val_accuracy: 0.5820
# Epoch 10/10
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9284 - accuracy: 0.6762 - val_loss: 1.1686 - val_accuracy: 0.5880
# Total training time to train  32_32_smaller_dataset 23.062344789505005
# 32/32 - 0s - loss: 1.1686 - accuracy: 0.5880
# Validation accuracy  0.5879999995231628

# %% [markdown]
# ### Compile, train and evaluate model for 16*16 resolution images on full size dataset

# %%
model3 = create_model(16, 1)
history3, model3 = train_model(model3, '16_16_complete', train_images_16_16, train_labels, test_images_16_16, test_labels)
evaluate_model('16_16_complete', model3, history3, test_images_16_16, test_labels)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29c856c10> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29c856c10> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1556/1563 [============================>.] - ETA: 0s - loss: 1.6827 - accuracy: 0.3863WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17fe19d30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17fe19d30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.6817 - accuracy: 0.3866 - val_loss: 1.2615 - val_accuracy: 0.5477
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.2032 - accuracy: 0.5729 - val_loss: 1.1261 - val_accuracy: 0.5959
# Epoch 3/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0569 - accuracy: 0.6266 - val_loss: 1.0896 - val_accuracy: 0.6198
# Epoch 4/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9220 - accuracy: 0.6747 - val_loss: 1.0276 - val_accuracy: 0.6349
# Epoch 5/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8159 - accuracy: 0.7186 - val_loss: 1.0665 - val_accuracy: 0.6322
# Epoch 6/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7046 - accuracy: 0.7548 - val_loss: 1.0667 - val_accuracy: 0.6365
# Epoch 7/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6110 - accuracy: 0.7839 - val_loss: 1.1058 - val_accuracy: 0.6432
# Epoch 8/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5209 - accuracy: 0.8180 - val_loss: 1.1936 - val_accuracy: 0.6268
# Epoch 9/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4318 - accuracy: 0.8478 - val_loss: 1.3874 - val_accuracy: 0.6073
# Epoch 10/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3620 - accuracy: 0.8720 - val_loss: 1.3785 - val_accuracy: 0.6312
# Total training time to train  16_16_complete 99.6360330581665
# 313/313 - 1s - loss: 1.3785 - accuracy: 0.6312
# Validation accuracy  0.6312000155448914

# %% [markdown]
# ### Compile, train and evaluate model for 16*16 resolution images on half size dataset

# %%
validation_16_16_data = train_images_16_16[49000:]
validation_16_16_labels = train_labels[49000:]

# %%
model4 = create_model(16, 1)
history4, model4 = train_model(model4, '16_16_smaller_dataset', test_images_16_16, test_labels, validation_16_16_data, validation_16_16_labels)
evaluate_model('16_16_smaller_datatset', model4, history4, validation_16_16_data, validation_16_16_labels)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29b1f5550> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x29b1f5550> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 309/313 [============================>.] - ETA: 0s - loss: 1.9653 - accuracy: 0.2761WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x29b1f5f70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x29b1f5f70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9624 - accuracy: 0.2773 - val_loss: 1.6495 - val_accuracy: 0.4120
# Epoch 2/10
# 313/313 [==============================] - 2s 6ms/step - loss: 1.5361 - accuracy: 0.4559 - val_loss: 1.4773 - val_accuracy: 0.4520
# Epoch 3/10
# 313/313 [==============================] - 2s 6ms/step - loss: 1.3773 - accuracy: 0.4977 - val_loss: 1.3783 - val_accuracy: 0.5140
# Epoch 4/10
# 313/313 [==============================] - 2s 6ms/step - loss: 1.2636 - accuracy: 0.5488 - val_loss: 1.4590 - val_accuracy: 0.4840
# Epoch 5/10
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1797 - accuracy: 0.5776 - val_loss: 1.2672 - val_accuracy: 0.5490
# Epoch 6/10
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0326 - accuracy: 0.6374 - val_loss: 1.3570 - val_accuracy: 0.5160
# Epoch 7/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9445 - accuracy: 0.6654 - val_loss: 1.3077 - val_accuracy: 0.5480
# Epoch 8/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7979 - accuracy: 0.7151 - val_loss: 1.3758 - val_accuracy: 0.5500
# Epoch 9/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6676 - accuracy: 0.7696 - val_loss: 1.4386 - val_accuracy: 0.5370
# Epoch 10/10
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5256 - accuracy: 0.8240 - val_loss: 1.5699 - val_accuracy: 0.5360
# Total training time to train  16_16_smaller_dataset 20.33338475227356
# 32/32 - 0s - loss: 1.5699 - accuracy: 0.5360
# Validation accuracy  0.5360000133514404

# %% [markdown]
# ### Predicting using this model

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[60]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[60]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# automobile

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[2000]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[2000]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# horse

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[10000]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[10000]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# automobile

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[20]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[500]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# dog

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[9000]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[9000]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# deer

# %%
plt.figure()
plt.imshow(Image.fromarray((train_images[6000]*255).astype(np.uint8)))
plt.colorbar()
plt.grid(False)
plt.show()

image = train_images[6000]
idx = np.argmax(model1.predict(image[np.newaxis,:]))
print(class_names[idx])
# Out:
# frog
